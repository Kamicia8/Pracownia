# %%
import json
import pandas as pd

with open("results1000.json", "r") as f:
    results = json.load(f)

df = pd.DataFrame(results)

denoising_metrics = ["mse_denoised", "rmse_denoised", "mae_denoised", "mape_denoised"]

for metrics in denoising_metrics:

    best_per_function = df.loc[df.groupby("function")[metrics].idxmin()]
    print(f"Najlepsze ustawienia dla każdej funkcji (najniższy {metrics}):")
    print(best_per_function[["function", "T", "beta", "training_loss_function", "epochs", metrics]])

    best_model = df.loc[df[metrics].idxmin()]
    print(f"\nNajlepszy model globalnie (najniższy {metrics}):")
    print(best_model[["function", "T", "beta", "training_loss_function", "epochs", metrics]])
# Out:
# Najlepsze ustawienia dla każdej funkcji (najniższy mse_denoised):
#    function    T beta training_loss_function  epochs  mse_denoised
# 42      exp  100  exp                    MSE    1000      0.222576
# 57      inv  100  exp                   RMSE    1000      0.224884
# 63    log10  100  exp                    MAE    1000      0.193319
# 54     poly  100  exp                   RMSE    1000      0.202939
# 46     relu  100  exp                    MSE    1000      0.198286
# 45  sigmoid  100  exp                    MSE    1000      0.186894
# 60      sin  100  exp                    MAE    1000      0.192345
# 68   sin_1x  100  exp                    MAE    1000      0.183687
# 51      tan  100  exp                   RMSE    1000      0.225703
# 49    zin_2  100  exp                    MSE    1000      0.181275
#
# Najlepszy model globalnie (najniższy mse_denoised):
# function                     zin_2
# T                              100
# beta                           exp
# ...

# %%
with open("results5000.json", "r") as f:
    results = json.load(f)

df = pd.DataFrame(results)

denoising_metrics = ["mse_denoised", "rmse_denoised", "mae_denoised", "mape_denoised"]

for metrics in denoising_metrics:

    best_per_function = df.loc[df.groupby("function")[metrics].idxmin()]
    print(f"Najlepsze ustawienia dla każdej funkcji (najniższy {metrics}):")
    print(best_per_function[["function", "T", "beta", "training_loss_function", "epochs", metrics]])

    best_model = df.loc[df[metrics].idxmin()]
    print(f"\nNajlepszy model globalnie (najniższy {metrics}):")
    print(best_model[["function", "T", "beta", "training_loss_function", "epochs", metrics]])
# Out:
# Najlepsze ustawienia dla każdej funkcji (najniższy mse_denoised):
#     function    T    beta training_loss_function  epochs  mse_denoised
# 12       exp  100     exp                    MSE    5000      0.198622
# 107      inv  100     exp                   RMSE    5000      0.203669
# 163    log10  800     exp                   RMSE    5000      0.116389
# 94      poly  100  cosine                   RMSE    5000      0.143143
# 116     relu  100  linear                   RMSE    5000      0.118936
# 145  sigmoid  350  linear                   RMSE    5000      0.095977
# 50       sin  350  linear                    MSE    5000      0.125922
# 68    sin_1x  800  cosine                    MSE    5000      0.101869
# 111      tan  100  linear                   RMSE    5000      0.146212
# 169    zin_2  800     exp                   RMSE    5000      0.105537
#
# Najlepszy model globalnie (najniższy mse_denoised):
# function                   sigmoid
# ...

# %%
with open("results10000.json", "r") as f:
    results = json.load(f)

df = pd.DataFrame(results)

denoising_metrics = ["mse_denoised", "rmse_denoised", "mae_denoised", "mape_denoised"]

for metrics in denoising_metrics:

    best_per_function = df.loc[df.groupby("function")[metrics].idxmin()]
    print(f"Najlepsze ustawienia dla każdej funkcji (najniższy {metrics}):")
    print(best_per_function[["function", "T", "beta", "training_loss_function", "epochs", metrics]])

    best_model = df.loc[df[metrics].idxmin()]
    print(f"\nNajlepszy model globalnie (najniższy {metrics}):")
    print(best_model[["function", "T", "beta", "training_loss_function", "epochs", metrics]])
# Out:
# Najlepsze ustawienia dla każdej funkcji (najniższy mse_denoised):
#     function    T    beta training_loss_function  epochs  mse_denoised
# 91       exp  100     exp                   RMSE   10000      0.156655
# 15       inv  100     exp                    MSE   10000      0.159885
# 119    log10  350     exp                   RMSE   10000      0.067629
# 93      poly  100     exp                   RMSE   10000      0.086053
# 122     relu  350     exp                   RMSE   10000      0.048264
# 148  sigmoid  800     exp                   RMSE   10000      0.036804
# 63       sin  800     exp                    MSE   10000      0.049699
# 34    sin_1x  350  cosine                    MSE   10000      0.040829
# 35     zin_2  350  cosine                    MSE   10000      0.048581
#
# Najlepszy model globalnie (najniższy mse_denoised):
# function                   sigmoid
# T                              800
# beta                           exp
# ...
